# %%
import pandas as pd
import numpy as np
import scipy as cp
import matplotlib.pyplot as plt
import math
print("Set up")
# Out:
# Set up

# %%
data5 = pd.read_csv("../data/lol.csv")
data5
# Out:
#            nu     v
# 0   30000.000  5.00
# 1     300.000  5.20
# 2      30.000  5.20
# 3       3.000  5.20
# 4       0.003  5.20
# 5    3000.000  5.20
# 6   10000.000  5.20
# 7   20000.000  5.00
# 8   15000.000  5.08
# 9   11000.000  5.16
# 10  12000.000  5.16
# 11  13000.000  5.12
# 12  14000.000  5.12
# 13  16000.000  5.08
# 14  17000.000  5.04
# 15  18000.000  5.04
# 16  19000.000  5.04

# %%
data5["k"] = data5["v"]/5
data5 = data5.sort_values(by="nu")
data5
# Out:
#            nu     v      k
# 4       0.003  5.20  1.040
# 3       3.000  5.20  1.040
# 2      30.000  5.20  1.040
# 1     300.000  5.20  1.040
# 5    3000.000  5.20  1.040
# 6   10000.000  5.20  1.040
# 9   11000.000  5.16  1.032
# 10  12000.000  5.16  1.032
# 11  13000.000  5.12  1.024
# 12  14000.000  5.12  1.024
# 8   15000.000  5.08  1.016
# 13  16000.000  5.08  1.016
# 14  17000.000  5.04  1.008
# 15  18000.000  5.04  1.008
# 16  19000.000  5.04  1.008
# 7   20000.000  5.00  1.000
# 0   30000.000  5.00  1.000

# %%
plt.plot(data5.nu, data5.k)
plt.xlabel("$\\nu$, кГц")
plt.ylabel("$K$")
plt.title("АЧХ")
plt.savefig("../img/ach")

# %%
data7 = pd.read_csv("../data/kek.csv")
data7 = data7.sort_values(by="lgnu")
data7
# Out:
#     dphi   lgnu
# 4  3.141  7.079
# 3  2.838  7.114
# 0  2.985  7.146
# 1  2.817  7.176
# 2  2.844  7.204

# %%
plt.plot(data7.lgnu, data7.dphi)
plt.xlabel("lg$\\nu$")
plt.ylabel("$\\Delta\phi$")
plt.title("Завиимость разности фаз от частоты сигнала")
plt.savefig("../img/kek.png")
