# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import math as m
print("Set up")
# Out:
# Set up

# %%
l = 9998e-4
l_err = 5e-5
mc = 8684e-4
mg = 3762e-4
mp = 757e-4
m_err = 5e-5

# %%
data1 = pd.read_csv("../data/data1.csv")
data1["a"] /= 100
data1["xc"] /= 100
data1
# Out:
#         a     xc      t
# 0   0.480  0.438  32.50
# 1   0.400  0.365  31.33
# 2   0.370  0.338  31.20
# 3   0.325  0.297  30.76
# 4   0.300  0.477  30.57
# 5   0.286  0.262  30.52
# 6   0.236  0.245  30.97
# 7   0.203  0.188  31.57
# 8   0.173  0.158  32.63
# 9   0.142  0.131  34.47
# 10  0.112  0.102  37.17
# 11  0.097  0.085  40.10
# 12  0.072  0.068  44.32

# %%
data2 = pd.read_csv("../data/data2.csv")
data2["xc"] /= 100
data2
# Out:
#       xc      t
# 0  0.407  32.62
# 1  0.401  32.29
# 2  0.394  31.93
# 3  0.385  31.57
# 4  0.379  31.22
# 5  0.372  30.92
# 6  0.361  30.49
# 7  0.358  30.32
# 8  0.347  30.03

# %%
def g_by_a(a, t):
    return (a**2+l**2/12)*4*m.pi**2/t**2/a

# %%
data1["g"] = g_by_a(data1["a"], data1["t"]/20)
data1
# Out:
#         a     xc      t         g
# 0   0.480  0.438  32.50  9.770714
# 1   0.400  0.365  31.33  9.785456
# 2   0.370  0.338  31.20  9.654419
# 3   0.325  0.297  30.76  9.701818
# 4   0.300  0.477  30.57  9.761266
# 5   0.286  0.262  30.52  9.786360
# 6   0.236  0.245  30.97  9.696782
# 7   0.203  0.188  31.57  9.717964
# 8   0.173  0.158  32.63  9.707271
# 9   0.142  0.131  34.47  9.683628
# 10  0.112  0.102  37.17  9.780961
# 11  0.097  0.085  40.10  9.386013
# 12  0.072  0.068  44.32  9.879899

# %%
data1["g"].std()/m.sqrt(len(data1["g"]))
# Out:
# 0.032053682975482924

# %%
data1["g"].mean()
# Out:
# 9.716350113517237

# %%
data2["y"] = data2["xc"]*(mg+mp+mc)/mg - mc/mg*(l/2-0.2)
data2["I"] = mc*((l)**2/12+(l/2-0.2)**2)+mg*data2["y"]**2
data2
# Out:
#       xc      t         y         I
# 0  0.407  32.62  0.736122  0.354295
# 1  0.401  32.29  0.715064  0.342799
# 2  0.394  31.93  0.690497  0.329809
# 3  0.385  31.57  0.658911  0.313774
# 4  0.379  31.22  0.637854  0.303501
# 5  0.372  30.92  0.613287  0.291938
# 6  0.361  30.49  0.574681  0.274685
# 7  0.358  30.32  0.564153  0.270174
# 8  0.347  30.03  0.525547  0.254348

# %%
def g_by_b(I, t, xc):
    return 4*m.pi**2*I/t**2/(mp+mg+mc)/xc

# %%
data2["g"] = g_by_b(data2["I"], data2["t"]/20, data2["xc"])
data2
# Out:
#       xc      t         y         I         g
# 0  0.407  32.62  0.736122  0.354295  9.784752
# 1  0.401  32.29  0.715064  0.342799  9.806323
# 2  0.394  31.93  0.690497  0.329809  9.820082
# 3  0.385  31.57  0.658911  0.313774  9.780346
# 4  0.379  31.22  0.637854  0.303501  9.826587
# 5  0.372  30.92  0.613287  0.291938  9.817843
# 6  0.361  30.49  0.574681  0.274685  9.789487
# 7  0.358  30.32  0.564153  0.270174  9.818598
# 8  0.347  30.03  0.525547  0.254348  9.721549

# %%
data1
# Out:
#         a     xc      t         g
# 0   0.480  0.438  32.50  9.770714
# 1   0.400  0.365  31.33  9.785456
# 2   0.370  0.338  31.20  9.654419
# 3   0.325  0.297  30.76  9.701818
# 4   0.300  0.477  30.57  9.761266
# 5   0.286  0.262  30.52  9.786360
# 6   0.236  0.245  30.97  9.696782
# 7   0.203  0.188  31.57  9.717964
# 8   0.173  0.158  32.63  9.707271
# 9   0.142  0.131  34.47  9.683628
# 10  0.112  0.102  37.17  9.780961
# 11  0.097  0.085  40.10  9.386013
# 12  0.072  0.068  44.32  9.879899

# %%
plt.figure(figsize=(8,6), dpi=400) # размер графика
plt.ylabel("$u=T^2 a$, $с^2 \cdot м$") # подписи к осям
plt.xlabel("$v=a^2$, $м^2$")
plt.title('Рис.2. Наилучшая прямая для линеаризованной зависимости $T(a)$')
plt.grid(True) # сетка
plt.plot(data1["a"]**2, data1["t"]**2*data1["xc"]/400, '.')

# %%
data1=data1.drop(4)
data1
# Out:
#         a     xc      t         g
# 0   0.480  0.438  32.50  9.770714
# 1   0.400  0.365  31.33  9.785456
# 2   0.370  0.338  31.20  9.654419
# 3   0.325  0.297  30.76  9.701818
# 5   0.286  0.262  30.52  9.786360
# 6   0.236  0.245  30.97  9.696782
# 7   0.203  0.188  31.57  9.717964
# 8   0.173  0.158  32.63  9.707271
# 9   0.142  0.131  34.47  9.683628
# 10  0.112  0.102  37.17  9.780961
# 11  0.097  0.085  40.10  9.386013
# 12  0.072  0.068  44.32  9.879899

# %%
plt.figure(figsize=(8,6), dpi=400) # размер графика
plt.ylabel("$u=T^2 a$, $с^2 \cdot м$") # подписи к осям
plt.xlabel("$v=a^2$, $м^2$")
plt.title('Рис.2. Наилучшая прямая для линеаризованной зависимости $T(a)$')
plt.grid(True) # сетка
x = data1["a"]**2
y = data1["t"]**2*data1["xc"]/400
plt.plot(x, y, '.')

# %%
k, b = np.polyfit(x, y, 1)
plt.figure(figsize=(8,6), dpi=400) # размер графика
plt.ylabel("$u=T^2 a$, $с^2 \cdot м$") # подписи к осям
plt.xlabel("$v=a^2$, $м^2$")
plt.title('Рис.2. Наилучшая прямая для линеаризованной зависимости $T(a)$')
plt.grid(True) # сетка
x = data1["a"]**2
y = data1["t"]**2*data1["xc"]/400
plt.plot(x, y, '.')
plt.axline((0, b), (0.2*k+b))
# Out:
# /usr/lib/python3.10/site-packages/matplotlib/axes/_base.py:2480: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   xys = np.asarray(xys)
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In [86], line 10
#       8 y = data1["t"]**2*data1["xc"]/400
#       9 plt.plot(x, y, '.')
# ---> 10 plt.axline((0, b), (0.2*k+b))
#
# File /usr/lib/python3.10/site-packages/matplotlib/pyplot.py:2379, in axline(xy1, xy2, slope, **kwargs)
#    2377 @_copy_docstring_and_deprecators(Axes.axline)
#    2378 def axline(xy1, xy2=None, *, slope=None, **kwargs):
# -> 2379     return gca().axline(xy1, xy2=xy2, slope=slope, **kwargs)
#
# File /usr/lib/python3.10/site-packages/matplotlib/axes/_axes.py:886, in Axes.axline(self, xy1, xy2, slope, **kwargs)
#     884 self._children.append(line)
#     885 line._remove_method = self._children.remove
# --> 886 self.update_datalim(datalim)
#     888 self._request_autoscale_view()
#     889 return line
#
# File /usr/lib/python3.10/site-packages/matplotlib/axes/_base.py:2481, in _AxesBase.update_datalim(self, xys, updatex, updatey)
#    2463 """
#    2464 Extend the `~.Axes.dataLim` Bbox to include the given points.
#    2465
#    (...)
#    2478     Whether to update the x/y limits.
#    2479 """
#    2480 xys = np.asarray(xys)
# -> 2481 if not np.any(np.isfinite(xys)):
#    2482     return
#    2483 self.dataLim.update_from_data_xy(xys, self.ignore_existing_data_limits,
#    2484                                  updatex=updatex, updatey=updatey)
#
# TypeError: ufunc 'isfinite' not supported for the input types, and the inputs could not be safely coerced to any supported types according to the casting rule ''safe''
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File /usr/lib/python3.10/site-packages/IPython/core/formatters.py:339, in BaseFormatter.__call__(self, obj)
#     337     pass
#     338 else:
# --> 339     return printer(obj)
#     340 # Finally look for special method names
#     341 method = get_real_method(obj, self.print_method)
#
# File /usr/lib/python3.10/site-packages/IPython/core/pylabtools.py:151, in print_figure(fig, fmt, bbox_inches, base64, **kwargs)
#     148     from matplotlib.backend_bases import FigureCanvasBase
#     149     FigureCanvasBase(fig)
# --> 151 fig.canvas.print_figure(bytes_io, **kw)
#     152 data = bytes_io.getvalue()
#     153 if fmt == 'svg':
#
# File /usr/lib/python3.10/site-packages/matplotlib/backend_bases.py:2295, in FigureCanvasBase.print_figure(self, filename, dpi, facecolor, edgecolor, orientation, format, bbox_inches, pad_inches, bbox_extra_artists, backend, **kwargs)
#    2289     renderer = _get_renderer(
#    2290         self.figure,
#    2291         functools.partial(
#    2292             print_method, orientation=orientation)
#    2293     )
#    2294     with getattr(renderer, "_draw_disabled", nullcontext)():
# -> 2295         self.figure.draw(renderer)
#    2297 if bbox_inches:
#    2298     if bbox_inches == "tight":
#
# File /usr/lib/python3.10/site-packages/matplotlib/artist.py:73, in _finalize_rasterization.<locals>.draw_wrapper(artist, renderer, *args, **kwargs)
#      71 @wraps(draw)
#      72 def draw_wrapper(artist, renderer, *args, **kwargs):
# ---> 73     result = draw(artist, renderer, *args, **kwargs)
#      74     if renderer._rasterizing:
#      75         renderer.stop_rasterizing()
#
# File /usr/lib/python3.10/site-packages/matplotlib/artist.py:50, in allow_rasterization.<locals>.draw_wrapper(artist, renderer)
#      47     if artist.get_agg_filter() is not None:
#      48         renderer.start_filter()
# ---> 50     return draw(artist, renderer)
#      51 finally:
#      52     if artist.get_agg_filter() is not None:
#
# File /usr/lib/python3.10/site-packages/matplotlib/figure.py:2837, in Figure.draw(self, renderer)
#    2834         # ValueError can occur when resizing a window.
#    2836 self.patch.draw(renderer)
# -> 2837 mimage._draw_list_compositing_images(
#    2838     renderer, self, artists, self.suppressComposite)
#    2840 for sfig in self.subfigs:
#    2841     sfig.draw(renderer)
#
# File /usr/lib/python3.10/site-packages/matplotlib/image.py:132, in _draw_list_compositing_images(renderer, parent, artists, suppress_composite)
#     130 if not_composite or not has_images:
#     131     for a in artists:
# --> 132         a.draw(renderer)
#     133 else:
#     134     # Composite any adjacent images together
#     135     image_group = []
#
# File /usr/lib/python3.10/site-packages/matplotlib/artist.py:50, in allow_rasterization.<locals>.draw_wrapper(artist, renderer)
#      47     if artist.get_agg_filter() is not None:
#      48         renderer.start_filter()
# ---> 50     return draw(artist, renderer)
#      51 finally:
#      52     if artist.get_agg_filter() is not None:
#
# File /usr/lib/python3.10/site-packages/matplotlib/axes/_base.py:3091, in _AxesBase.draw(self, renderer)
#    3088         a.draw(renderer)
#    3089     renderer.stop_rasterizing()
# -> 3091 mimage._draw_list_compositing_images(
#    3092     renderer, self, artists, self.figure.suppressComposite)
#    3094 renderer.close_group('axes')
#    3095 self.stale = False
#
# File /usr/lib/python3.10/site-packages/matplotlib/image.py:132, in _draw_list_compositing_images(renderer, parent, artists, suppress_composite)
#     130 if not_composite or not has_images:
#     131     for a in artists:
# --> 132         a.draw(renderer)
#     133 else:
#     134     # Composite any adjacent images together
#     135     image_group = []
#
# File /usr/lib/python3.10/site-packages/matplotlib/lines.py:1460, in _AxLine.draw(self, renderer)
#    1458 def draw(self, renderer):
#    1459     self._transformed_path = None  # Force regen.
# -> 1460     super().draw(renderer)
#
# File /usr/lib/python3.10/site-packages/matplotlib/artist.py:50, in allow_rasterization.<locals>.draw_wrapper(artist, renderer)
#      47     if artist.get_agg_filter() is not None:
#      48         renderer.start_filter()
# ---> 50     return draw(artist, renderer)
#      51 finally:
#      52     if artist.get_agg_filter() is not None:
#
# File /usr/lib/python3.10/site-packages/matplotlib/lines.py:750, in Line2D.draw(self, renderer)
#     748 renderer.open_group('line2d', self.get_gid())
#     749 if self._lineStyles[self._linestyle] != '_draw_nothing':
# --> 750     tpath, affine = (self._get_transformed_path()
#     751                      .get_transformed_path_and_affine())
#     752     if len(tpath.vertices):
#     753         gc = renderer.new_gc()
#
# File /usr/lib/python3.10/site-packages/matplotlib/lines.py:710, in Line2D._get_transformed_path(self)
#     708 """Return this line's `~matplotlib.transforms.TransformedPath`."""
#     709 if self._transformed_path is None:
# --> 710     self._transform_path()
#     711 return self._transformed_path
#
# File /usr/lib/python3.10/site-packages/matplotlib/lines.py:705, in Line2D._transform_path(self, subslice)
#     703 else:
#     704     _path = self._path
# --> 705 self._transformed_path = TransformedPath(_path, self.get_transform())
#
# File /usr/lib/python3.10/site-packages/matplotlib/lines.py:1424, in _AxLine.get_transform(self)
#    1419 points_transform = self._transform - ax.transData + ax.transScale
#    1421 if self._xy2 is not None:
#    1422     # two points were given
#    1423     (x1, y1), (x2, y2) = \
# -> 1424         points_transform.transform([self._xy1, self._xy2])
#    1425     dx = x2 - x1
#    1426     dy = y2 - y1
#
# File /usr/lib/python3.10/site-packages/matplotlib/transforms.py:1798, in AffineBase.transform(self, values)
#    1796 def transform(self, values):
#    1797     # docstring inherited
# -> 1798     return self.transform_affine(values)
#
# File /usr/lib/python3.10/site-packages/matplotlib/transforms.py:1867, in Affine2DBase.transform_affine(self, points)
#    1865     tpoints = affine_transform(points.data, mtx)
#    1866     return np.ma.MaskedArray(tpoints, mask=np.ma.getmask(points))
# -> 1867 return affine_transform(points, mtx)
#
# ValueError: setting an array element with a sequence. The requested array has an inhomogeneous shape after 1 dimensions. The detected shape was (2,) + inhomogeneous part.
