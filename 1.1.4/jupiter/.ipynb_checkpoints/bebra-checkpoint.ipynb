# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

print("Setup")
# Out:
# Setup

# %%
hist_data = pd.read_csv("../data/hist.csv").values
hist_data
# Out:
# array([[4.000e+00, 2.000e+00, 5.000e-03],
#        [5.000e+00, 1.000e+00, 2.500e-03],
#        [6.000e+00, 1.300e+01, 3.250e-02],
#        [7.000e+00, 1.400e+01, 3.500e-02],
#        [8.000e+00, 2.600e+01, 6.500e-02],
#        [9.000e+00, 3.100e+01, 7.750e-02],
#        [1.000e+01, 4.300e+01, 1.075e-01],
#        [1.100e+01, 4.600e+01, 1.150e-01],
#        [1.200e+01, 4.000e+01, 1.000e-01],
#        [1.300e+01, 4.600e+01, 1.150e-01],
#        [1.400e+01, 3.000e+01, 7.500e-02],
#        [1.500e+01, 2.600e+01, 6.500e-02],
#        [1.600e+01, 2.300e+01, 5.750e-02],
#        [1.700e+01, 2.600e+01, 6.500e-02],
#        [1.800e+01, 1.100e+01, 2.750e-02],
#        [1.900e+01, 6.000e+00, 1.500e-02],
#        [2.000e+01, 6.000e+00, 1.500e-02],
#        [2.100e+01, 3.000e+00, 7.500e-03],
#        [2.200e+01, 3.000e+00, 7.500e-03],
#        [2.300e+01, 2.000e+00, 5.000e-03],
#        [2.400e+01, 1.000e+00, 2.500e-03],
#        [2.500e+01, 1.000e+00, 2.500e-03]])

# %%
plt.xlabel("$n$, число срабатываний")
plt.ylabel("$\omega_n$, доля случаев")
plt.hist(hist_data[:,0], len(cases), weights=hist_data[:,1]/sum(hist_data[:,1]))
# Out:
# (array([0.005 , 0.0025, 0.0325, 0.035 , 0.065 , 0.0775, 0.1075, 0.115 ,
#         0.1   , 0.115 , 0.075 , 0.065 , 0.0575, 0.065 , 0.0275, 0.015 ,
#         0.015 , 0.0075, 0.0075, 0.005 , 0.0025, 0.0025]),
#  array([ 4.        ,  4.95454545,  5.90909091,  6.86363636,  7.81818182,
#          8.77272727,  9.72727273, 10.68181818, 11.63636364, 12.59090909,
#         13.54545455, 14.5       , 15.45454545, 16.40909091, 17.36363636,
#         18.31818182, 19.27272727, 20.22727273, 21.18181818, 22.13636364,
#         23.09090909, 24.04545455, 25.        ]),
#  <BarContainer object of 22 artists>)

# %%
plt.hist(hist_data[::2,0]+hist_data[1::2,0], len(cases)//2, weights=(hist_data[::2,1]+hist_data[1::2,0])/sum(hist_data[:,1]))
# Out:
# (array([0.0175, 0.05  , 0.0875, 0.135 , 0.1325, 0.1125, 0.1   , 0.075 ,
#         0.0675, 0.065 , 0.065 ]),
#  array([ 9.        , 12.63636364, 16.27272727, 19.90909091, 23.54545455,
#         27.18181818, 30.81818182, 34.45454545, 38.09090909, 41.72727273,
#         45.36363636, 49.        ]),
#  <BarContainer object of 11 artists>)
