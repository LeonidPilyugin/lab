# %% [markdown]
# # Import

# %%
import lab
import lab.plot
import lab.data
import lab.mmath as mmath
import lab.utils as utils
import lab.arr as arr
import lab.linfit as lf
import lab.constants as const
import lab.utils as utils
from lab.unit import unit as u
from uncertainties import ufloat
import matplotlib.pyplot as plt
import numpy as np
print("Import done!")
# Out:
# Import done!

# %% [markdown]
# # Read data

# %%
U_burn = ufloat(2180, 10) * u("V")
d = 0.2 * u("mm")
l = 5.2 * u("mm")

# %%
vah = lab.data.Data("../data/vah.csv")
vah["I"] = vah["I"].set_err(lambda arr: arr * 0.002 + 0.0004 * u("mA"))
vah["U"] = vah["U"].set_err(lambda arr: arr * 0.003 + 0.0004 * u("V"))
vah.head()
# Out:
#                    U                            I
# 0  34.30+/-0.10 volt  0.5287+/-0.0015 milliampere
# 1  33.07+/-0.10 volt  0.7965+/-0.0020 milliampere
# 2  32.25+/-0.10 volt  1.1050+/-0.0026 milliampere
# 3  31.70+/-0.10 volt  1.4120+/-0.0032 milliampere
# 4  31.05+/-0.09 volt    1.713+/-0.004 milliampere

# %%
zh5 = lab.data.Data("../data/zh5.csv")
zh5["I"] = zh5["I"].set_err(lambda arr: np.absolute(arr) * 0.002 + 0.0004 * u("microampere"))
zh5["U"] = zh5["U"].set_err(lambda arr: np.absolute(arr) * 0.003 + 0.0004 * u("V"))
zh5.head()
# Out:
#                    U                          I
# 0  25.10+/-0.08 volt  113.12+/-0.23 microampere
# 1  22.05+/-0.07 volt  110.38+/-0.22 microampere
# 2  19.04+/-0.06 volt  107.66+/-0.22 microampere
# 3  16.04+/-0.05 volt  104.07+/-0.21 microampere
# 4  13.05+/-0.04 volt   98.61+/-0.20 microampere

# %%
zh3 = lab.data.Data("../data/zh3.csv")
zh3["I"] = zh3["I"].set_err(lambda arr: np.absolute(arr) * 0.002 + 0.0004 * u("microampere"))
zh3["U"] = zh3["U"].set_err(lambda arr: np.absolute(arr) * 0.003 + 0.0004 * u("V"))
zh3.head(5)
# Out:
#                     U                          I
# 0  -25.10+/-0.08 volt  -51.37+/-0.10 microampere
# 1  -22.02+/-0.07 volt  -49.57+/-0.10 microampere
# 2  -19.05+/-0.06 volt  -47.86+/-0.10 microampere
# 3  -15.98+/-0.05 volt  -46.06+/-0.09 microampere
# 4  -12.98+/-0.04 volt  -43.44+/-0.09 microampere

# %%
zh15 = lab.data.Data("../data/zh15.csv")
zh15["I"] = zh15["I"].set_err(lambda arr: np.absolute(arr) * 0.002 + 0.0004 * u("microampere"))
zh15["U"] = zh15["U"].set_err(lambda arr: np.absolute(arr) * 0.003 + 0.0004 * u("V"))
zh15.head(5)
# Out:
#                    U                         I
# 0  25.10+/-0.08 volt  35.16+/-0.07 microampere
# 1  21.97+/-0.07 volt  33.86+/-0.07 microampere
# 2  18.97+/-0.06 volt  32.61+/-0.07 microampere
# 3  15.99+/-0.05 volt  31.39+/-0.06 microampere
# 4  13.01+/-0.04 volt  30.06+/-0.06 microampere

# %% [markdown]
# # Texify primary data

# %%
utils.totex(vah, file="../tex/vah_primary.tex")
for z, i in zip((zh5, zh3, zh15), (5, 3, 1.5)):
    utils.totex(z, file=f"../tex/zh{i}_primary.tex")

# %% [markdown]
# # Compute

# %%
vah["Up"] = vah["U"] * 10
vah.head()
# Out:
#                    U                            I                Up
# 0  34.30+/-0.10 volt  0.5287+/-0.0015 milliampere  343.0+/-1.0 volt
# 1  33.07+/-0.10 volt  0.7965+/-0.0020 milliampere  330.7+/-1.0 volt
# 2  32.25+/-0.10 volt  1.1050+/-0.0026 milliampere  322.5+/-1.0 volt
# 3  31.70+/-0.10 volt  1.4120+/-0.0032 milliampere  317.0+/-1.0 volt
# 4  31.05+/-0.09 volt    1.713+/-0.004 milliampere  310.5+/-0.9 volt

# %% [markdown]
# # Plot

# %%
vah_plot = lab.plot.Plot(yl="$I_p$", xl="$U_p$")
vah_plot.plot(vah["Up"][:15], vah["I"][:15], fmt=".", label="убывание", color="red")
vah_plot.plot(vah["Up"][15:], vah["I"][15:], fmt=".", label="возрастание", color="blue")
vah_plot.ax.legend()
vah_plot.save("../img/vah.png")

# %%
zh_plot = lab.plot.Plot(yl="$I$", xl="$U$")
zh_plot.plot(zh5["U"], zh5["I"] - 8.235 * u("microampere"), label="5 мА")
zh_plot.plot(zh3["U"], zh3["I"] - 11.75 * u("microampere"), label="3 мА")
zh_plot.plot(zh15["U"], zh15["I"] - 6 * u("microampere"), label="1,5 мА")
zh_plot.ax.legend()
zh_plot.save("../img/zh.png")

# %%
zh15
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>U</th>
#       <th>I</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>25.10+/-0.08 volt</td>
#       <td>35.16+/-0.07 microampere</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>21.97+/-0.07 volt</td>
#       <td>33.86+/-0.07 microampere</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>18.97+/-0.06 volt</td>
#       <td>32.61+/-0.07 microampere</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>15.99+/-0.05 volt</td>
#       <td>31.39+/-0.06 microampere</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>13.01+/-0.04 volt</td>
#       <td>30.06+/-0.06 microampere</td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td>10.045+/-0.031 volt</td>
#       <td>28.14+/-0.06 microampere</td>
#     </tr>
#     <tr>
#       <th>6</th>
#       <td>8.069+/-0.025 volt</td>
#       <td>26.09+/-0.05 microampere</td>
#     </tr>
#     <tr>
#       <th>7</th>
#       <td>6.002+/-0.018 volt</td>
#       <td>22.96+/-0.05 microampere</td>
#     </tr>
#     <tr>
#       <th>8</th>
#       <td>4.004+/-0.012 volt</td>
#       <td>18.66+/-0.04 microampere</td>
#     </tr>
#     <tr>
#       <th>9</th>
#       <td>2.032+/-0.006 volt</td>
#       <td>13.100+/-0.027 microampere</td>
#     </tr>
#     <tr>
#       <th>10</th>
#       <td>0.0095+/-0.0004 volt</td>
#       <td>6.300+/-0.013 microampere</td>
#     </tr>
#     <tr>
#       <th>11</th>
#       <td>-0.0101+/-0.0004 volt</td>
#       <td>5.700+/-0.012 microampere</td>
#     </tr>
#     <tr>
#       <th>12</th>
#       <td>-2.025+/-0.006 volt</td>
#       <td>-1.4200+/-0.0032 microampere</td>
#     </tr>
#     <tr>
#       <th>13</th>
#       <td>-4.029+/-0.012 volt</td>
#       <td>-7.480+/-0.015 microampere</td>
#     </tr>
#     <tr>
#       <th>14</th>
#       <td>-6.012+/-0.018 volt</td>
#       <td>-12.440+/-0.025 microampere</td>
#     </tr>
#     <tr>
#       <th>15</th>
#       <td>-7.996+/-0.024 volt</td>
#       <td>-16.000+/-0.032 microampere</td>
#     </tr>
#     <tr>
#       <th>16</th>
#       <td>-9.982+/-0.030 volt</td>
#       <td>-18.51+/-0.04 microampere</td>
#     </tr>
#     <tr>
#       <th>17</th>
#       <td>-13.08+/-0.04 volt</td>
#       <td>-20.62+/-0.04 microampere</td>
#     </tr>
#     <tr>
#       <th>18</th>
#       <td>-15.95+/-0.05 volt</td>
#       <td>-21.50+/-0.04 microampere</td>
#     </tr>
#     <tr>
#       <th>19</th>
#       <td>-18.97+/-0.06 volt</td>
#       <td>-22.25+/-0.04 microampere</td>
#     </tr>
#     <tr>
#       <th>20</th>
#       <td>-22.07+/-0.07 volt</td>
#       <td>-23.02+/-0.05 microampere</td>
#     </tr>
#     <tr>
#       <th>21</th>
#       <td>-25.10+/-0.08 volt</td>
#       <td>-23.77+/-0.05 microampere</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %%
zh3
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>U</th>
#       <th>I</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>-25.10+/-0.08 volt</td>
#       <td>-51.37+/-0.10 microampere</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>-22.02+/-0.07 volt</td>
#       <td>-49.57+/-0.10 microampere</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>-19.05+/-0.06 volt</td>
#       <td>-47.86+/-0.10 microampere</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>-15.98+/-0.05 volt</td>
#       <td>-46.06+/-0.09 microampere</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>-12.98+/-0.04 volt</td>
#       <td>-43.44+/-0.09 microampere</td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td>-9.990+/-0.030 volt</td>
#       <td>-38.59+/-0.08 microampere</td>
#     </tr>
#     <tr>
#       <th>6</th>
#       <td>-8.053+/-0.025 volt</td>
#       <td>-33.49+/-0.07 microampere</td>
#     </tr>
#     <tr>
#       <th>7</th>
#       <td>-6.004+/-0.018 volt</td>
#       <td>-25.99+/-0.05 microampere</td>
#     </tr>
#     <tr>
#       <th>8</th>
#       <td>-3.993+/-0.012 volt</td>
#       <td>-16.450+/-0.033 microampere</td>
#     </tr>
#     <tr>
#       <th>9</th>
#       <td>-2.027+/-0.006 volt</td>
#       <td>-5.300+/-0.011 microampere</td>
#     </tr>
#     <tr>
#       <th>10</th>
#       <td>0.0093+/-0.0004 volt</td>
#       <td>11.750+/-0.024 microampere</td>
#     </tr>
#     <tr>
#       <th>11</th>
#       <td>2.014+/-0.006 volt</td>
#       <td>24.06+/-0.05 microampere</td>
#     </tr>
#     <tr>
#       <th>12</th>
#       <td>3.985+/-0.012 volt</td>
#       <td>34.49+/-0.07 microampere</td>
#     </tr>
#     <tr>
#       <th>13</th>
#       <td>6.041+/-0.019 volt</td>
#       <td>43.24+/-0.09 microampere</td>
#     </tr>
#     <tr>
#       <th>14</th>
#       <td>8.089+/-0.025 volt</td>
#       <td>49.71+/-0.10 microampere</td>
#     </tr>
#     <tr>
#       <th>15</th>
#       <td>9.997+/-0.030 volt</td>
#       <td>54.01+/-0.11 microampere</td>
#     </tr>
#     <tr>
#       <th>16</th>
#       <td>13.01+/-0.04 volt</td>
#       <td>58.27+/-0.12 microampere</td>
#     </tr>
#     <tr>
#       <th>17</th>
#       <td>16.04+/-0.05 volt</td>
#       <td>60.89+/-0.12 microampere</td>
#     </tr>
#     <tr>
#       <th>18</th>
#       <td>19.03+/-0.06 volt</td>
#       <td>62.90+/-0.13 microampere</td>
#     </tr>
#     <tr>
#       <th>19</th>
#       <td>22.00+/-0.07 volt</td>
#       <td>64.86+/-0.13 microampere</td>
#     </tr>
#     <tr>
#       <th>20</th>
#       <td>25.10+/-0.08 volt</td>
#       <td>66.93+/-0.13 microampere</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %%
zh5
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>U</th>
#       <th>I</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>25.10+/-0.08 volt</td>
#       <td>113.12+/-0.23 microampere</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>22.05+/-0.07 volt</td>
#       <td>110.38+/-0.22 microampere</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>19.04+/-0.06 volt</td>
#       <td>107.66+/-0.22 microampere</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>16.04+/-0.05 volt</td>
#       <td>104.07+/-0.21 microampere</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>13.05+/-0.04 volt</td>
#       <td>98.61+/-0.20 microampere</td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td>10.046+/-0.031 volt</td>
#       <td>89.85+/-0.18 microampere</td>
#     </tr>
#     <tr>
#       <th>6</th>
#       <td>7.990+/-0.024 volt</td>
#       <td>81.27+/-0.16 microampere</td>
#     </tr>
#     <tr>
#       <th>7</th>
#       <td>6.037+/-0.019 volt</td>
#       <td>70.69+/-0.14 microampere</td>
#     </tr>
#     <tr>
#       <th>8</th>
#       <td>4.006+/-0.012 volt</td>
#       <td>57.41+/-0.12 microampere</td>
#     </tr>
#     <tr>
#       <th>9</th>
#       <td>2.084+/-0.007 volt</td>
#       <td>44.09+/-0.09 microampere</td>
#     </tr>
#     <tr>
#       <th>10</th>
#       <td>0.0034+/-0.0004 volt</td>
#       <td>26.84+/-0.05 microampere</td>
#     </tr>
#     <tr>
#       <th>11</th>
#       <td>-0.0052+/-0.0004 volt</td>
#       <td>-5.300+/-0.011 microampere</td>
#     </tr>
#     <tr>
#       <th>12</th>
#       <td>-2.009+/-0.006 volt</td>
#       <td>-20.83+/-0.04 microampere</td>
#     </tr>
#     <tr>
#       <th>13</th>
#       <td>-4.005+/-0.012 volt</td>
#       <td>-35.69+/-0.07 microampere</td>
#     </tr>
#     <tr>
#       <th>14</th>
#       <td>-6.007+/-0.018 volt</td>
#       <td>-49.77+/-0.10 microampere</td>
#     </tr>
#     <tr>
#       <th>15</th>
#       <td>-7.999+/-0.024 volt</td>
#       <td>-61.98+/-0.12 microampere</td>
#     </tr>
#     <tr>
#       <th>16</th>
#       <td>-10.027+/-0.030 volt</td>
#       <td>-71.44+/-0.14 microampere</td>
#     </tr>
#     <tr>
#       <th>17</th>
#       <td>-13.01+/-0.04 volt</td>
#       <td>-81.14+/-0.16 microampere</td>
#     </tr>
#     <tr>
#       <th>18</th>
#       <td>-16.01+/-0.05 volt</td>
#       <td>-87.02+/-0.17 microampere</td>
#     </tr>
#     <tr>
#       <th>19</th>
#       <td>-19.02+/-0.06 volt</td>
#       <td>-90.63+/-0.18 microampere</td>
#     </tr>
#     <tr>
#       <th>20</th>
#       <td>-22.02+/-0.07 volt</td>
#       <td>-93.64+/-0.19 microampere</td>
#     </tr>
#     <tr>
#       <th>21</th>
#       <td>-25.09+/-0.08 volt</td>
#       <td>-96.65+/-0.19 microampere</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %%
k_15_0, b_15_0 = lf.chi2(zh15["U"][9:13], zh15["I"][9:13])
print(k_15_0, b_15_0)
k_3_0, b_3_0 = lf.chi2(zh3["U"][9:12], zh3["I"][9:12])
print(k_3_0, b_3_0)
k_5_0, b_5_0 = None, None
print(k_5_0, b_5_0)
# Out:
# 3.63+/-0.09 microampere / volt 5.93+/-0.16 microampere
# 7.8+/-0.6 microampere / volt 10.6+/-1.1 microampere
# None None

# %%
k_15_l, b_15_l = lf.chi2(zh15["U"][:5], (zh15["I"] - 6 * u("microampere"))[:5])
print("1.5 left:", utils.texify(b_15_l))
k_15_r, b_15_r = lf.chi2(zh15["U"][18:], (zh15["I"] - 6 * u("microampere"))[18:])
print("1.5 right:", utils.texify(b_15_r))

k_3_l, b_3_l = lf.chi2(zh3["U"][:5], (zh3["I"] - 11.75 * u("microampere"))[:5])
print("3 left:", utils.texify(b_3_l))
k_3_r, b_3_r = lf.chi2(zh3["U"][17:], (zh3["I"] - 11.75 * u("microampere"))[17:])
print("3 right:", utils.texify(b_3_r))

k_5_l, b_5_l = lf.chi2(zh5["U"][:5], (zh5["I"] - 8.235 * u("microampere"))[:5])
print("5 left:", utils.texify(b_5_l))
k_5_r, b_5_r = lf.chi2(zh5["U"][18:], (zh5["I"] - 8.235 * u("microampere"))[18:])
print("5 right:", utils.texify(b_5_r))
# Out:
# 1.5 left: 18{,}63 \pm 0{,}07\;\text{мкА}
# 1.5 right: \left(-23543{,}3 \pm 1{,}5\right)\cdot 10^{-3}\;\text{мкА}
# 3 left: -47{,}1 \pm 0{,}7\;\text{мкА}
# 3 right: 38{,}47 \pm 0{,}03\;\text{мкА}
# 5 left: 76 \pm 2\;\text{мкА}
# 5 right: -78{,}5 \pm 0{,}8\;\text{мкА}

# %% [markdown]
# # Plot lines and save

# %%
p1.line(k1, b1, color="black")
p1.save("../img/plot1.png")

# %%
p2.line(k2, b2, color="black")
p2.save("../img/plot2.png")

# %% [markdown]
# # Result

# %%
L1 = const.R * data["T"].arr.mean() ** 2 / data["p"].arr.mean() * k1
L2 = -const.R * k2
print(f"L1 = {L1}\nL2 = {L2}")
# Out:
# L1 = (3.86+/-0.10)e+04 joule / mole
# L2 = (3.96+/-0.05)e+04 joule / mole

# %%
utils.totex(L1)
utils.totex(L2)
# Out:
# \left(3{,}86\pm0{,}10\right)\cdot 10^{4}\;\text{Дж} / \text{моль}
# \left(3{,}96\pm0{,}05\right)\cdot 10^{4}\;\text{Дж} / \text{моль}

# %% [markdown]
# # Texify intermediate data

# %%
utils.totex(data, file="../tex/table2.tex", columns={
    "T": "T",
    "h1": "h_1",
    "h2": "h_2",
    "p": "P",
    "1/T": "T^{-1}",
    "lnp": "\ln P",
})
