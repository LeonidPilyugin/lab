# %% [markdown]
# # Import

# %%
import sys
sys.path.append("/home/leonid/github.com/LeonidPilyugin/upt")

# %%
from upt import *
print("Import done!")
# Out:
# Import done!

# %% [markdown]
# # Read data

# %%
na = Data("../data/na.csv")
hgy1 = Data("../data/hgy1.csv")
hgy2 = Data("../data/hgy2.csv")
hgg = Data("../data/hgg.csv")

# %% [markdown]
# # Texify primary data

# %%
#totex(na, file="../tex/na.tex")
#totex(hgy1, file="../tex/hgy1.tex")
#totex(hgy2, file="../tex/hgy2.tex")
#totex(hgg, file="../tex/hgyg.tex")

# %% [markdown]
# # Add values

# %%
dr_na = Value(164.400, 0.001, u.mm) - Value(163.951, 0.001, u.mm)
dr_hgy1 = Value(176.810, 0.001, u.mm) - Value(172.740, 0.001, u.mm)
dr_hgy2 = Value(169.020, 0.001, u.mm) - Value(166.242, 0.001, u.mm)
dr_hgg = Value(177.850, 0.001, u.mm) - Value(175.814, 0.001, u.mm)

L_na = Value(90, 0, u.micrometer)
L_hg = Value(100, 0, u.micrometer)

f_na = Value(50, 0, u.mm)
f_hg = Value(110, 0, u.mm)

lambda_na = Value(5893, 0, u.angstrom)
lambda_hgg = Value(5461, 0, u.angstrom)

# %%
dr_hgy2
# Out:
# 2.7780 +/- 0.0014, millimeter

# %%
na["d"] = Array([na["x"][i] - na["x"][19 - i] for i in range(20)])
na_nd = na[10:]
na_nd["n"] = na_nd["n"] - Array([Value(10)] * len(na_nd.df))
del na_nd["x"]
na_nd
# Out:
# /home/leonid/github.com/LeonidPilyugin/upt/upt/data.py:70: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.df[key] = value.arr
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>n</th>
#       <th>d</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>10</th>
#       <td>1</td>
#       <td>0 +/- 1400, millimeter</td>
#     </tr>
#     <tr>
#       <th>11</th>
#       <td>2</td>
#       <td>0 +/- 1400, millimeter</td>
#     </tr>
#     <tr>
#       <th>12</th>
#       <td>3</td>
#       <td>0 +/- 1400, millimeter</td>
#     </tr>
#     <tr>
#       <th>13</th>
#       <td>4</td>
#       <td>0 +/- 1400, millimeter</td>
#     </tr>
#     <tr>
#       <th>14</th>
#       <td>5</td>
#       <td>0 +/- 1400, millimeter</td>
#     </tr>
#     <tr>
#       <th>15</th>
#       <td>6</td>
#       <td>0 +/- 1400, millimeter</td>
#     </tr>
#     <tr>
#       <th>16</th>
#       <td>7</td>
#       <td>0 +/- 1400, millimeter</td>
#     </tr>
#     <tr>
#       <th>17</th>
#       <td>8</td>
#       <td>0 +/- 1400, millimeter</td>
#     </tr>
#     <tr>
#       <th>18</th>
#       <td>9</td>
#       <td>0 +/- 1400, millimeter</td>
#     </tr>
#     <tr>
#       <th>19</th>
#       <td>10</td>
#       <td>0 +/- 1400, millimeter</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %%
hgg["d"] = Array([hgg["x"][i] - hgg["x"][9 - i] for i in range(10)])
hgg_nd = hgg[5:]
hgg_nd["n"] = hgg_nd["n"] - Array([Value(5)] * len(hgg_nd.df))
hgg_nd["n"] = hgg_nd["n"]
del hgg_nd["x"]
hgg_nd
# Out:
# /home/leonid/github.com/LeonidPilyugin/upt/upt/data.py:70: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.df[key] = value.arr
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>n</th>
#       <th>d</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>5</th>
#       <td>1</td>
#       <td>0 +/- 1400, millimeter</td>
#     </tr>
#     <tr>
#       <th>6</th>
#       <td>2</td>
#       <td>0 +/- 1400, millimeter</td>
#     </tr>
#     <tr>
#       <th>7</th>
#       <td>3</td>
#       <td>0 +/- 1400, millimeter</td>
#     </tr>
#     <tr>
#       <th>8</th>
#       <td>4</td>
#       <td>0 +/- 1400, millimeter</td>
#     </tr>
#     <tr>
#       <th>9</th>
#       <td>5</td>
#       <td>0 +/- 1400, millimeter</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %%
k_hg, b_hg = chi2(hgg_nd["n"], hgg_nd["d"] ** 2)
k_hg, b_hg
# Out:
# (268.2 +/- 1.2, millimeter ** 2, -120 +/- 3, millimeter ** 2)

# %%
p1 = Plot()
p1.plot(hgg_nd["n"], hgg_nd["d"] ** 2, fmt=".")
p1.xlabel("$i$")
p1.ylabel("$d^2$")
p1.line(k_hg, b_hg, color="red", linestyle='dashed')
p1.title("Зеленая линия ртути $\lambda = 5461 \; Å$, $k = 268 \pm 1 \; мм^2$")
p1.save("../img/plothg.png")
# Out:
# <>:6: SyntaxWarning: invalid escape sequence '\l'
# <>:6: SyntaxWarning: invalid escape sequence '\l'
# /tmp/ipykernel_25793/1138392237.py:6: SyntaxWarning: invalid escape sequence '\l'
#   p1.ax.set_title("Зеленая линия ртути $\lambda = 5461 \; Å$, $k = 268 \pm 1 \; мм^2$")
# /tmp/ipykernel_25793/1138392237.py:6: SyntaxWarning: invalid escape sequence '\l'
#   p1.ax.set_title("Зеленая линия ртути $\lambda = 5461 \; Å$, $k = 268 \pm 1 \; мм^2$")
# ---------------------------------------------------------------------------
# RecursionError                            Traceback (most recent call last)
# Cell In[12], line 5
#       3 p1.xlabel("$i$")
#       4 p1.ylabel("$d^2$")
# ----> 5 p1.line(k_hg, b_hg, color="red", linestyle='dashed')
#       6 p1.ax.set_title("Зеленая линия ртути $\lambda = 5461 \; Å$, $k = 268 \pm 1 \; мм^2$")
#       7 p1.save("../img/plothg.png")
#
# File ~/github.com/LeonidPilyugin/upt/upt/plot.py:57, in Plot.line(self, k, b, alpha, **kwargs)
#      54 b1 = b.n + b.s
#      55 b2 = b.n - b.s
# ---> 57 self.line(k, b, color="black", linestyle=(0, (5, 10)))
#      59 for l1, l2 in combinations([(k1, b1), (k1, b2), (k2, b1), (k2, b2)], 2):
#      60     _k1, _b1 = l1
#
# File ~/github.com/LeonidPilyugin/upt/upt/plot.py:57, in Plot.line(self, k, b, alpha, **kwargs)
#      54 b1 = b.n + b.s
#      55 b2 = b.n - b.s
# ---> 57 self.line(k, b, color="black", linestyle=(0, (5, 10)))
#      59 for l1, l2 in combinations([(k1, b1), (k1, b2), (k2, b1), (k2, b2)], 2):
#      60     _k1, _b1 = l1
#
#     [... skipping similar frames: Plot.line at line 57 (2959 times)]
#
# File ~/github.com/LeonidPilyugin/upt/upt/plot.py:57, in Plot.line(self, k, b, alpha, **kwargs)
#      54 b1 = b.n + b.s
#      55 b2 = b.n - b.s
# ---> 57 self.line(k, b, color="black", linestyle=(0, (5, 10)))
#      59 for l1, l2 in combinations([(k1, b1), (k1, b2), (k2, b1), (k2, b2)], 2):
#      60     _k1, _b1 = l1
#
# File ~/github.com/LeonidPilyugin/upt/upt/plot.py:46, in Plot.line(self, k, b, alpha, **kwargs)
#      44     self._update_labels()
#      45 else:
# ---> 46     k = k.to(self._qy / self._qx)
#      47     b = b.to(self._qy)
#      49 xi, xa = self.ax.get_xlim()
#
# File ~/github.com/LeonidPilyugin/upt/upt/value.py:352, in Value.to(self, units)
#     350 def to(self, units):
#     351     res = Value(0)
# --> 352     res._v = 1 * self._v
#     353     res.u = units
#     354     return res
#
# File ~/github.com/LeonidPilyugin/upt/.venv/lib/python3.12/site-packages/pint/facets/plain/quantity.py:1018, in PlainQuantity.__mul__(self, other)
#    1017 def __mul__(self, other):
# -> 1018     return self._mul_div(other, operator.mul)
#
# File ~/github.com/LeonidPilyugin/upt/.venv/lib/python3.12/site-packages/pint/facets/plain/quantity.py:101, in check_implemented.<locals>.wrapped(self, *args, **kwargs)
#      99 elif isinstance(other, list) and other and isinstance(other[0], type(self)):
#     100     return NotImplemented
# --> 101 return f(self, *args, **kwargs)
#
# File ~/github.com/LeonidPilyugin/upt/.venv/lib/python3.12/site-packages/pint/facets/plain/quantity.py:84, in ireduce_dimensions.<locals>.wrapped(self, *args, **kwargs)
#      82 try:
#      83     if result._REGISTRY.auto_reduce_dimensions:
# ---> 84         result.ito_reduced_units()
#      85 except AttributeError:
#      86     pass
#
# File ~/github.com/LeonidPilyugin/upt/.venv/lib/python3.12/site-packages/pint/facets/plain/qto.py:53, in ito_reduced_units(quantity)
#      47 """Return PlainQuantity scaled in place to reduced units, i.e. one unit per
#      48 dimension. This will not reduce compound units (e.g., 'J/kg' will not
#      49 be reduced to m**2/s**2), nor can it make use of contexts at this time.
#      50 """
#      52 # shortcuts in case we're dimensionless or only a single unit
# ---> 53 if quantity.dimensionless:
#      54     return quantity.ito({})
#      55 if len(quantity._units) == 1:
#
# File ~/github.com/LeonidPilyugin/upt/.venv/lib/python3.12/site-packages/pint/facets/plain/quantity.py:339, in PlainQuantity.dimensionless(self)
#     336 @property
#     337 def dimensionless(self) -> bool:
#     338     """ """
# --> 339     tmp = self.to_root_units()
#     341     return not bool(tmp.dimensionality)
#
# File ~/github.com/LeonidPilyugin/upt/.venv/lib/python3.12/site-packages/pint/facets/plain/quantity.py:555, in PlainQuantity.to_root_units(self)
#     551 """Return PlainQuantity rescaled to root units."""
#     553 _, other = self._REGISTRY._get_root_units(self._units)
# --> 555 magnitude = self._convert_magnitude_not_inplace(other)
#     557 return self.__class__(magnitude, other)
#
# File ~/github.com/LeonidPilyugin/upt/.venv/lib/python3.12/site-packages/pint/facets/plain/quantity.py:480, in PlainQuantity._convert_magnitude_not_inplace(self, other, *contexts, **ctx_kwargs)
#     477     with self._REGISTRY.context(*contexts, **ctx_kwargs):
#     478         return self._REGISTRY.convert(self._magnitude, self._units, other)
# --> 480 return self._REGISTRY.convert(self._magnitude, self._units, other)
#
# File ~/github.com/LeonidPilyugin/upt/.venv/lib/python3.12/site-packages/pint/facets/plain/registry.py:1041, in GenericPlainRegistry.convert(self, value, src, dst, inplace)
#    1038 if src == dst:
#    1039     return value
# -> 1041 return self._convert(value, src, dst, inplace)
#
# File ~/github.com/LeonidPilyugin/upt/.venv/lib/python3.12/site-packages/pint/facets/context/registry.py:405, in GenericContextRegistry._convert(self, value, src, dst, inplace)
#     401             src = self._active_ctx.transform(a, b, self, src)
#     403         value, src = src._magnitude, src._units
# --> 405 return super()._convert(value, src, dst, inplace)
#
# File ~/github.com/LeonidPilyugin/upt/.venv/lib/python3.12/site-packages/pint/facets/nonmultiplicative/registry.py:246, in GenericNonMultiplicativeRegistry._convert(self, value, src, dst, inplace)
#     241 # Conversion needs to consider if non-multiplicative (AKA offset
#     242 # units) are involved. Conversion is only possible if src and dst
#     243 # have at most one offset unit per dimension. Other rules are applied
#     244 # by validate and extract.
#     245 try:
# --> 246     src_offset_unit = self._validate_and_extract(src)
#     247 except ValueError as ex:
#     248     raise DimensionalityError(src, dst, extra_msg=f" - In source units, {ex}")
#
# File ~/github.com/LeonidPilyugin/upt/.venv/lib/python3.12/site-packages/pint/facets/nonmultiplicative/registry.py:166, in GenericNonMultiplicativeRegistry._validate_and_extract(self, units)
#     139 """Used to check if a given units is suitable for a simple
#     140 conversion.
#     141
#    (...)
#     158
#     159 """
#     161 # TODO: document what happens if autoconvert_offset_to_baseunit
#     162 # TODO: Clarify docs
#     163
#     164 # u is for unit, e is for exponent
#     165 nonmult_units = [
# --> 166     (u, e) for u, e in units.items() if not self._is_multiplicative(u)
#     167 ]
#     169 # Let's validate source offset units
#     170 if len(nonmult_units) > 1:
#     171     # More than one src offset unit is not allowed
#
# File ~/github.com/LeonidPilyugin/upt/.venv/lib/python3.12/site-packages/pint/facets/nonmultiplicative/registry.py:124, in GenericNonMultiplicativeRegistry._is_multiplicative(self, unit_name)
#     110 def _is_multiplicative(self, unit_name: str) -> bool:
#     111     """True if the unit is multiplicative.
#     112
#     113     Parameters
#    (...)
#     122         If the unit is not in the registry.
#     123     """
# --> 124     if unit_name in self._units:
#     125         return self._units[unit_name].is_multiplicative
#     127     # If the unit is not in the registry might be because it is not
#     128     # registered with its prefixed version.
#     129     # TODO: Might be better to register them.
#
# File /usr/lib/python3.12/collections/__init__.py:1030, in ChainMap.__contains__(self, key)
#    1029 def __contains__(self, key):
# -> 1030     return any(key in m for m in self.maps)
#
# RecursionError: maximum recursion depth exceeded

# %%
_L_hg = 4 * lambda_hgg * f_hg ** 2 / k_hg
_L_hg
# Out:
# 0.09856354628912953+/-0.00043671109513447273 <Unit('millimeter')>

# %%
k_na, b_na = lf.chi2(na_nd["n"].values, (na_nd["d"] ** 2).values)
k_na, b_na
# Out:
# (65.76270192889751+/-0.6292218819647714 <Unit('millimeter ** 2')>,
#  -30.801972128463888+/-2.4195419593985137 <Unit('millimeter ** 2')>)

# %%
p1 = Plot(yl="$d^2$", xl="$i$")
p1.plot(na_nd["n"].values, (na_nd["d"] ** 2).values, fmt=".")
p1.line(k_na, b_na, color="red", linestyle='dashed')
p1.ax.set_title("Линия натрия $\lambda = 5893 \; Å$, $k = 65{,}7 \pm 0{,}6 \; мм^2$")
p1.save("../img/plotna.png")

# %%
_L_na = 4 * lambda_na * f_na ** 2 / k_na
_L_na
# Out:
# 0.08961006508478771+/-0.0008573950300369151 <Unit('millimeter')>

# %%
4 * f_hg ** 2 / hgg_nd["d"].values[0] / dr_hgg
# Out:
# 1957.8407314363521+/-1.3789100512574366 <Unit('dimensionless')>
